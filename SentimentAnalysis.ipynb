# %% [markdown]
# <a href="https://colab.research.google.com/github/Adarshthakur-850/Sentiment_analysis/blob/main/SentimentAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install libraries
# !pip install snscrape
# !pip install transformers
# !pip install nltk
# !pip install pandas matplotlib seaborn

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re

from transformers import pipeline

import snscrape.modules.twitter as sntwitter

import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
# !pip install snscrape

# %%
# !pip install --upgrade certifi
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# %%
import requests
from bs4 import BeautifulSoup

query = "AI technology"

url = f"https://twitter.com/search?q={query}&src=typed_query&f=live"

response = requests.get(url, verify=False)

if response.status_code == 200:
    soup = BeautifulSoup(response.text, 'html.parser')
    tweets = soup.find_all('div', {'class': 'css-901oao'})

    for tweet in tweets:
        print(tweet.get_text())
else:
    print(f"Error fetching the page: {response.status_code}")
# Out:
# /usr/local/lib/python3.11/dist-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'twitter.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'x.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Error fetching the page: 400

# %%
# !pip install tweepy

# %% [markdown]
# Sentiment Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re
from transformers import pipeline
import snscrape.modules.twitter as sntwitter
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import ssl
import requests
from bs4 import BeautifulSoup
from PIL import Image
import io


def analyze_sentiment(text):
    classifier = pipeline("sentiment-analysis")
    result = classifier(text)[0]
    return result["label"], result["score"]

def analyze_image_sentiment(image):
  print("Image sentiment analysis not yet implemented.")
  return "Unknown", 0.0


from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))

  try:
    img = Image.open(io.BytesIO(uploaded[fn]))
    print("Image successfully opened.")

    label, score = analyze_image_sentiment(img)
    print(f"Image sentiment: {label}, score: {score}")

  except Exception as e:
    print(f"Error handling image: {e}")


text = "This is a great day!"
label, score = analyze_sentiment(text)
print(f"Sentiment: {label}, Score: {score}")
# Out:
#      <input type="file" id="files-8c53b55f-fe7b-45fb-b175-e028332c2a9f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8c53b55f-fe7b-45fb-b175-e028332c2a9f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
def analyze_emotion(text):
    classifier = pipeline("text-classification", model="j-hartmann/emotion-english-distilroberta-base")
    result = classifier(text)[0]
    return result["label"], result["score"]

text = "I am so happy today!"
emotion, score = analyze_emotion(text)
print(f"Emotion: {emotion}, Score: {score}")

text = "I feel so sad today."
emotion, score = analyze_emotion(text)
print(f"Emotion: {emotion}, Score: {score}")

text = "The weather is nice today."
emotion, score = analyze_emotion(text)
print(f"Emotion: {emotion}, Score: {score}")
# Out:
# config.json:   0%|          | 0.00/1.00k [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# pytorch_model.bin:   0%|          | 0.00/329M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/294 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# ...
